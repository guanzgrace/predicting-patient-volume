# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import datetime as dt

# %%
df = pd.read_csv("final_predictions.csv")

# %%
df.index = df["date"]

# %%
df.head()
# Out:
#           date   y_actual  dy_baseline     dy_ts     dy_nn    dy_rnn  \
# date
# 1/1/18  1/1/18   0.842912     3.071777  2.861262  2.184588  1.681090
# 1/2/18  1/2/18  10.383142     8.417969  8.615086  8.234965  7.771666
# 1/3/18  1/3/18   8.429119     8.085449  7.961201  8.052320  7.515713
# 1/4/18  1/4/18   1.685824     0.482422  1.311294  1.338094  1.009327
# 1/5/18  1/5/18   7.662835     6.400391  6.589701  6.250945  6.204715
#
#           osa_ts    osa_nn1  osa_rnn7    y_resp     ...       osa_nn1_r  \
# date                                                ...
# 1/1/18  2.669142   2.954190  1.548252  0.153257     ...        1.369373
# 1/2/18  8.384631  10.714353  8.461362  4.061303     ...        3.769319
# 1/3/18  7.943427   9.190865  7.582548  3.065134     ...        3.127298
# 1/4/18  1.147520   1.458251  1.062317  0.766284     ...        0.410463
# 1/5/18  6.694467   9.659932  6.644524  3.409962     ...        2.973706
#
# ...

# %%
df.index = pd.to_datetime(df.index)

# %%
fig, ax = plt.subplots(figsize=(15,6))
plt.scatter(df.index, df["y_actual"], marker='o', color='black', label='Actual')
plt.scatter(df.index, df["dy_baseline"], marker='3', color='blue', label='Dynamic Baseline')
plt.scatter(df.index, df["dy_ts"], marker='4', color='purple', label='Dynamic TS')
plt.scatter(df.index, df["dy_nn"], marker='1', color='green', label='Dynamic NN')
plt.scatter(df.index, df["dy_rnn"], marker='2', color='orange', label='Dynamic RNN')
plt.legend(loc=1)
plt.xlim((pd.datetime(2017,12,31), pd.datetime(2018,9,21)))
plt.xlabel("Date")
plt.ylabel("Sick Visits/FTP")
plt.title("Dynamic Model Predictions For All Visits")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
plt.scatter(df.index, df["y_resp"], marker='o', color='black', label='Actual')
plt.scatter(df.index, df["dy_baseline_r"], marker='3', color='blue', label='Dynamic Baseline')
plt.scatter(df.index, df["dy_ts_r"], marker='4', color='purple', label='Dynamic TS')
plt.scatter(df.index, df["dy_nn_r"], marker='1', color='green', label='Dynamic NN')
plt.scatter(df.index, df["dy_rnn_r"], marker='2', color='orange', label='Dynamic RNN')
plt.legend(loc=1)
plt.xlim((pd.datetime(2017,12,31), pd.datetime(2018,9,21)))
plt.xlabel("Date")
plt.ylabel("Sick Visits/FTP")
plt.title("Dynamic Model Predictions For Respiratory Visits")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
plt.scatter(df.index, df["y_nonresp"], marker='o', color='black', label='Actual')
plt.scatter(df.index, df["dy_baseline_nr"], marker='3', color='blue', label='Dynamic Baseline')
plt.scatter(df.index, df["dy_ts_nr"], marker='4', color='purple', label='Dynamic TS')
plt.scatter(df.index, df["dy_nn_nr"], marker='1', color='green', label='Dynamic NN')
plt.scatter(df.index, df["dy_rnn_nr"], marker='2', color='orange', label='Dynamic RNN')
plt.legend(loc=1)
plt.xlim((pd.datetime(2017,12,31), pd.datetime(2018,9,21)))
plt.xlabel("Date")
plt.ylabel("Sick Visits/FTP")
plt.title("Dynamic Model Predictions For Non-Respiratory Visits")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
plt.scatter(df.index, df["y_actual"], marker='o', color='black', label='Actual')
plt.scatter(df.index, df["osa_ts"], marker='.', color='purple', label='OSA TS')
plt.scatter(df.index, df["osa_nn1"], marker='.', color='green', label='OSA NN-1')
plt.scatter(df.index, df["osa_rnn7"], marker='.', color='orange', label='OSA RNN-7')
plt.legend(loc=1)
plt.xlim((pd.datetime(2017,12,31), pd.datetime(2018,9,21)))
plt.xlabel("Date")
plt.ylabel("Sick Visits/FTP")
plt.title("OSA Model Predictions For All Visits")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
plt.scatter(df.index, df["y_resp"], marker='o', color='black', label='Actual')
plt.scatter(df.index, df["osa_ts_r"], marker='.', color='purple', label='OSA TS')
plt.scatter(df.index, df["osa_nn1_r"], marker='.', color='green', label='OSA NN-1')
plt.scatter(df.index, df["osa_rnn7_r"], marker='.', color='orange', label='OSA RNN-7')
plt.legend(loc=1)
plt.xlim((pd.datetime(2017,12,31), pd.datetime(2018,9,21)))
plt.xlabel("Date")
plt.ylabel("Sick Visits/FTP")
plt.title("OSA Model Predictions For Respiratory Visits")
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,6))
plt.scatter(df.index, df["y_nonresp"], marker='o', color='black', label='Actual')
plt.scatter(df.index, df["osa_ts_nr"], marker='.', color='purple', label='OSA TS')
plt.scatter(df.index, df["osa_nn1_nr"], marker='.', color='green', label='OSA NN-1')
plt.scatter(df.index, df["osa_rnn7_nr"], marker='.', color='orange', label='OSA RNN-7')
plt.legend(loc=1)
plt.xlim((pd.datetime(2017,12,31), pd.datetime(2018,9,21)))
plt.xlabel("Date")
plt.ylabel("Sick Visits/FTP")
plt.title("OSA Model Predictions For Non-Respiratory Visits")
plt.show()

# %%
desc = pd.Series(df["dy_baseline_r"] - df["y_resp"]).describe()
iqr15 = 1.5 * (desc[6] - desc[4])
iqr_above = np.array([iqr15 for i in range(len(df))])
iqr_below = np.array([-1 * iqr15 for i in range(len(df))])

fig, ax = plt.subplots(figsize=(15,12))
plt.subplot(2, 1, 1)
plt.scatter(df.index, df["dy_baseline_r"] - df["y_resp"], marker='3', color='blue', label='Dynamic Baseline')
plt.scatter(df.index, df["dy_ts_r"] - df["y_resp"], marker='4', color='purple', label='Dynamic TS')
plt.scatter(df.index, df["osa_ts_r"] - df["y_resp"], marker='.', color='purple', label='OSA TS')
plt.scatter(df.index, df["dy_nn_r"] - df["y_resp"], marker='1', color='green', label='Dynamic NN')
plt.scatter(df.index, df["osa_nn1_r"] - df["y_resp"], marker='.', color='green', label='OSA NN-1')
plt.scatter(df.index, df["dy_rnn_r"] - df["y_resp"], marker='2', color='orange', label='Dynamic RNN')
plt.scatter(df.index, df["osa_rnn7_r"] - df["y_resp"], marker='.', color='orange', label='OSA RNN-7')
plt.plot(df.index, iqr_above, '-', color='teal', label='±1.5 * Baseline IQR range')
plt.plot(df.index, iqr_below, '-', color='teal')
plt.axvline(dt.datetime(2018,1,14), color='r', linestyle=':', label='Approximate Range of Outbreak')
plt.axvline(dt.datetime(2018,3,1), color='r', linestyle=':')
plt.legend(loc=0)
plt.xlim((pd.datetime(2017,12,31), pd.datetime(2018,9,21)))
plt.xlabel("Date")
plt.ylabel("Error (Sick Visits/FTP)")
plt.title("Dynamic and OSA Model Errors on Respiratory Visits for January-September 2018")

plt.subplot(2, 1, 2)
plt.scatter(df.index, df["dy_baseline_r"] - df["y_resp"], marker='3', color='blue', label='Dynamic Baseline')
plt.scatter(df.index, df["dy_ts_r"] - df["y_resp"], marker='4', color='purple', label='Dynamic TS')
plt.scatter(df.index, df["osa_ts_r"] - df["y_resp"], marker='.', color='purple', label='OSA TS')
plt.scatter(df.index, df["dy_nn_r"] - df["y_resp"], marker='1', color='green', label='Dynamic NN')
plt.scatter(df.index, df["osa_nn1_r"] - df["y_resp"], marker='.', color='green', label='OSA NN-1')
plt.scatter(df.index, df["dy_rnn_r"] - df["y_resp"], marker='2', color='orange', label='Dynamic RNN')
plt.scatter(df.index, df["osa_rnn7_r"] - df["y_resp"], marker='.', color='orange', label='OSA RNN-7')
plt.plot(df.index, iqr_above, '-', color='teal', label='±1.5 * Baseline IQR range')
plt.plot(df.index, iqr_below, '-', color='teal')
plt.legend(loc=0)
plt.xlim((pd.datetime(2018,1,14), pd.datetime(2018,3,1)))
plt.xlabel("Date")
plt.ylabel("Error (Sick Visits/FTP)")
plt.title("Dynamic and OSA Model Errors on Respiratory Visits for the Approximate Range of Outbreak")

plt.show()

# %%
desc = pd.Series(df["dy_baseline_nr"] - df["y_nonresp"]).describe()
iqr15 = 1.5 * (desc[6] - desc[4])
iqr_above = np.array([iqr15 for i in range(len(df))])
iqr_below = np.array([-1 * iqr15 for i in range(len(df))])

fig, ax = plt.subplots(figsize=(15, 6))
plt.scatter(df.index, df["dy_baseline_nr"] - df["y_nonresp"], marker='3', color='blue', label='Dynamic Baseline')
plt.scatter(df.index, df["dy_ts_nr"] - df["y_nonresp"], marker='4', color='purple', label='Dynamic TS')
plt.scatter(df.index, df["osa_ts_nr"] - df["y_nonresp"], marker='.', color='purple', label='OSA TS')
plt.scatter(df.index, df["dy_nn_nr"] - df["y_nonresp"], marker='1', color='green', label='Dynamic NN')
plt.scatter(df.index, df["osa_nn1_nr"] - df["y_nonresp"], marker='.', color='green', label='OSA NN-1')
plt.scatter(df.index, df["dy_rnn_nr"] - df["y_nonresp"], marker='2', color='orange', label='Dynamic RNN')
plt.scatter(df.index, df["osa_rnn7_nr"] - df["y_nonresp"], marker='.', color='orange', label='OSA RNN-7')
plt.plot(df.index, iqr_above, '-', color='teal', label='±1.5 * Baseline IQR range')
plt.plot(df.index, iqr_below, '-', color='teal')
plt.axvline(dt.datetime(2018,1,14), color='r', linestyle=':', label='Approximate Range of Outbreak')
plt.axvline(dt.datetime(2018,3,1), color='r', linestyle=':')
plt.legend(loc=0)
plt.xlim((pd.datetime(2017,12,31), pd.datetime(2018,9,21)))
plt.xlabel("Date")
plt.ylabel("Error (Sick Visits/FTP)")
plt.title("Dynamic and OSA Model Errors on Non-Respiratory Visits for January-September 2018")

plt.show()

# %%
visits = pd.read_csv("DatasetForMLHC.csv") 
visits.index = pd.to_datetime(visits["Unnamed: 0"])
visits.index = pd.DatetimeIndex(visits.index.values)

# %%
fig, ax = plt.subplots(figsize=(15,14))
    
plt.subplot(3, 1, 1)
plt.scatter(visits.index, visits["AdjCount"], marker='.', color='black', label='Sick visits/FTP')
plt.ylabel("Sick Visits/FTP")
plt.title("(A) All Sick Visits/FTP: January 2010 - September 2018")

plt.subplot(3, 1, 2)
plt.scatter(visits.index, visits["AdjCount"], marker='.', color='black', label='Sick visits/FTP')
plt.xlim((pd.datetime(2017,9,20), pd.datetime(2018,9,20)))
plt.ylabel("Sick Visits/FTP")
plt.title("(B) September 20, 2017 to September 20, 2018")

plt.subplot(3, 1, 3)
plt.scatter(visits.index, visits["AdjCount"], marker='o', color='black', label='Sick visits/FTP')
plt.xlim((pd.datetime(2018,6,30), pd.datetime(2018,9,20)))
plt.ylim(0, 8)
plt.xlabel("Date")
plt.ylabel("Sick Visits/FTP")
plt.title("(C) Monday June 30, 2017 to Thursday September 20, 2018")

plt.show()
